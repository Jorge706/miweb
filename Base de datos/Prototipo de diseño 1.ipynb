-- %% [markdown]
-- # [Pro1]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Pro1]    Script Date: 07/06/2023 07:41:52 p. m. ******/
CREATE DATABASE [Pro1]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'Pro1', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\Pro1.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'Pro1_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\Pro1_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [Pro1] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Pro1].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Pro1] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Pro1] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Pro1] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Pro1] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Pro1] SET ARITHABORT OFF 
GO
ALTER DATABASE [Pro1] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [Pro1] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Pro1] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Pro1] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Pro1] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Pro1] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Pro1] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Pro1] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Pro1] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Pro1] SET  ENABLE_BROKER 
GO
ALTER DATABASE [Pro1] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Pro1] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Pro1] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Pro1] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Pro1] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Pro1] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Pro1] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Pro1] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [Pro1] SET  MULTI_USER 
GO
ALTER DATABASE [Pro1] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Pro1] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Pro1] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Pro1] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [Pro1] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [Pro1] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [Pro1] SET QUERY_STORE = ON
GO
ALTER DATABASE [Pro1] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Cliente_Evento]

-- %%
USE [Pro1]
GO

-- %%
/****** Object:  Table [dbo].[Cliente_Evento]    Script Date: 07/06/2023 07:41:52 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cliente_Evento](
	[Cliente_Evento_id] [int] NOT NULL,
	[Cliente_id] [int] NULL,
	[Evento_id] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Cliente_Evento_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Clientes]

-- %%
/****** Object:  Table [dbo].[Clientes]    Script Date: 07/06/2023 07:41:52 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Clientes](
	[ID_cliente] [int] NOT NULL,
	[nombre] [varchar](20) NULL,
	[apellido] [varchar](20) NULL,
	[correo] [nchar](20) NULL,
	[curp] [nvarchar](18) NULL,
	[permiso] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_cliente] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Clientes_permisos]

-- %%
/****** Object:  Table [dbo].[Clientes_permisos]    Script Date: 07/06/2023 07:41:52 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Clientes_permisos](
	[ID_CP] [int] NOT NULL,
	[Cliente_id] [int] NULL,
	[Permiso_id] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_CP] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Contrato_tercero]

-- %%
/****** Object:  Table [dbo].[Contrato_tercero]    Script Date: 07/06/2023 07:41:52 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Contrato_tercero](
	[ID_Contrato] [int] NOT NULL,
	[Descripcion] [varchar](30) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_Contrato] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Descripcion_E]

-- %%
/****** Object:  Table [dbo].[Descripcion_E]    Script Date: 07/06/2023 07:41:52 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Descripcion_E](
	[ID_DE] [int] NOT NULL,
	[Tipo_Evento_ID] [int] NULL,
	[Contrato_ID] [int] NULL,
	[Caracteristicas] [varchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_DE] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Eventos]

-- %%
/****** Object:  Table [dbo].[Eventos]    Script Date: 07/06/2023 07:41:52 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Eventos](
	[Evento_id] [int] NOT NULL,
	[Nombre_evento] [varchar](100) NULL,
	[Descripcion] [int] NULL,
	[Paquete_id] [int] NULL,
	[Cliente_id] [int] NULL,
	[fecha] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Evento_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Fecha]

-- %%
/****** Object:  Table [dbo].[Fecha]    Script Date: 07/06/2023 07:41:52 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Fecha](
	[ID_Fecha] [int] NOT NULL,
	[Fecha_Inicio] [date] NULL,
	[Fecha_Fin] [date] NULL,
	[descripcion] [varchar](30) NULL,
	[horas] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_Fecha] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Horas]

-- %%
/****** Object:  Table [dbo].[Horas]    Script Date: 07/06/2023 07:41:52 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Horas](
	[ID_Hora] [int] NOT NULL,
	[Hora_inicio] [time](7) NULL,
	[Hora_fin] [time](7) NULL,
	[Fecha_id] [int] NULL,
	[Horas_Extra_Id] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_Hora] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[HorasExtra]

-- %%
/****** Object:  Table [dbo].[HorasExtra]    Script Date: 07/06/2023 07:41:52 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[HorasExtra](
	[ID_Hora] [int] NOT NULL,
	[Cantidad_horas] [int] NULL,
	[Costo] [decimal](10, 2) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_Hora] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Paquetes]

-- %%
/****** Object:  Table [dbo].[Paquetes]    Script Date: 07/06/2023 07:41:52 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Paquetes](
	[ID_Paquete] [int] NOT NULL,
	[Nombre_Paquete] [varchar](40) NULL,
	[Descripcion] [varchar](50) NULL,
	[Precio_Base] [decimal](10, 2) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_Paquete] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Permisos_Cliente]

-- %%
/****** Object:  Table [dbo].[Permisos_Cliente]    Script Date: 07/06/2023 07:41:52 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Permisos_Cliente](
	[ID_permiso] [int] NOT NULL,
	[permiso] [varchar](20) NULL,
	[descripcion] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_permiso] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tipo_Evento]

-- %%
/****** Object:  Table [dbo].[Tipo_Evento]    Script Date: 07/06/2023 07:41:52 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tipo_Evento](
	[ID_TEvento] [int] NOT NULL,
	[Descripcion] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_TEvento] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [cliente]

-- %%
ALTER TABLE [dbo].[Cliente_Evento]  WITH CHECK ADD  CONSTRAINT [cliente] FOREIGN KEY([Evento_id])
REFERENCES [dbo].[Eventos] ([Evento_id])
GO
ALTER TABLE [dbo].[Cliente_Evento] CHECK CONSTRAINT [cliente]
GO

-- %% [markdown]
-- # [FK__Cliente_E__Clien__403A8C7D]

-- %%
ALTER TABLE [dbo].[Cliente_Evento]  WITH CHECK ADD FOREIGN KEY([Cliente_id])
REFERENCES [dbo].[Clientes] ([ID_cliente])
GO

-- %% [markdown]
-- # [ck_permiso]

-- %%
ALTER TABLE [dbo].[Clientes]  WITH CHECK ADD  CONSTRAINT [ck_permiso] FOREIGN KEY([permiso])
REFERENCES [dbo].[Clientes_permisos] ([ID_CP])
GO
ALTER TABLE [dbo].[Clientes] CHECK CONSTRAINT [ck_permiso]
GO

-- %% [markdown]
-- # [FK__Clientes___Clien__3B75D760]

-- %%
ALTER TABLE [dbo].[Clientes_permisos]  WITH CHECK ADD FOREIGN KEY([Cliente_id])
REFERENCES [dbo].[Clientes] ([ID_cliente])
GO

-- %% [markdown]
-- # [FK__Clientes___Permi__3C69FB99]

-- %%
ALTER TABLE [dbo].[Clientes_permisos]  WITH CHECK ADD FOREIGN KEY([Permiso_id])
REFERENCES [dbo].[Permisos_Cliente] ([ID_permiso])
GO

-- %% [markdown]
-- # [FK__Descripci__Contr__52593CB8]

-- %%
ALTER TABLE [dbo].[Descripcion_E]  WITH CHECK ADD FOREIGN KEY([Contrato_ID])
REFERENCES [dbo].[Contrato_tercero] ([ID_Contrato])
GO

-- %% [markdown]
-- # [FK__Descripci__Tipo___5165187F]

-- %%
ALTER TABLE [dbo].[Descripcion_E]  WITH CHECK ADD FOREIGN KEY([Tipo_Evento_ID])
REFERENCES [dbo].[Tipo_Evento] ([ID_TEvento])
GO

-- %% [markdown]
-- # [FK__Eventos__Cliente__5629CD9C]

-- %%
ALTER TABLE [dbo].[Eventos]  WITH CHECK ADD FOREIGN KEY([Cliente_id])
REFERENCES [dbo].[Cliente_Evento] ([Cliente_Evento_id])
GO

-- %% [markdown]
-- # [FK__Eventos__Descrip__5812160E]

-- %%
ALTER TABLE [dbo].[Eventos]  WITH CHECK ADD FOREIGN KEY([Descripcion])
REFERENCES [dbo].[Descripcion_E] ([ID_DE])
GO

-- %% [markdown]
-- # [FK__Eventos__fecha__571DF1D5]

-- %%
ALTER TABLE [dbo].[Eventos]  WITH CHECK ADD FOREIGN KEY([fecha])
REFERENCES [dbo].[Fecha] ([ID_Fecha])
GO

-- %% [markdown]
-- # [FK__Eventos__Paquete__5535A963]

-- %%
ALTER TABLE [dbo].[Eventos]  WITH CHECK ADD FOREIGN KEY([Paquete_id])
REFERENCES [dbo].[Paquetes] ([ID_Paquete])
GO

-- %% [markdown]
-- # [FK__Fecha__horas__49C3F6B7]

-- %%
ALTER TABLE [dbo].[Fecha]  WITH CHECK ADD FOREIGN KEY([horas])
REFERENCES [dbo].[Horas] ([ID_Hora])
GO

-- %% [markdown]
-- # [ck_horas_fecha]

-- %%
ALTER TABLE [dbo].[Horas]  WITH CHECK ADD  CONSTRAINT [ck_horas_fecha] FOREIGN KEY([Horas_Extra_Id])
REFERENCES [dbo].[Fecha] ([ID_Fecha])
GO
ALTER TABLE [dbo].[Horas] CHECK CONSTRAINT [ck_horas_fecha]
GO

-- %% [markdown]
-- # [FK__Horas__Horas_Ext__46E78A0C]

-- %%
ALTER TABLE [dbo].[Horas]  WITH CHECK ADD FOREIGN KEY([Horas_Extra_Id])
REFERENCES [dbo].[HorasExtra] ([ID_Hora])
GO

-- %% [markdown]
-- # [Pro1]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Pro1] SET  READ_WRITE 
GO
